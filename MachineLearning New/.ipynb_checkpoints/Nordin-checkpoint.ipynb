# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
FifaDbfile = pd.read_csv('NewFifa.csv')

# %%
from sklearn.model_selection import train_test_split 
fifatrain, fifatest = train_test_split(FifaDbfile, test_size = 0.25)

# %%
FifaDbfile['Weight']
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18142    134lbs
# 18143    170lbs
# 18144    148lbs
# 18145    154lbs
# 18146    176lbs
# Name: Weight, Length: 18147, dtype: object

# %%
list_weight = FifaDbfile['Weight']
list_new_weight = [] 

for i in list_new_weight: 
    convert_lbs_to_kg = (float(list_new_weight)*2.2046)  
print (convert_lbs_to_kg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-15786a10350f> in <module>
#       4 for i in list_new_weight:
#       5     convert_lbs_to_kg = (float(list_new_weight)*2.2046)
# ----> 6 print (convert_lbs_to_kg)
#       7
#
# NameError: name 'convert_lbs_to_kg' is not defined

# %%
list_weight = FifaDbfile['Weight']

for i in list_weight:
    
    lbs_to_kg = i.strip('lbs')
    convert_weight = float(lbs_to_kg)/2.2046
    roundup_weight = round(convert_weight)  
    
    print (roundup_weight)
# Out:
# 72
# 83
# 68
# 76
# 70
# 74
# 66
# 86
# 82
# 87
# 80
# 76
# 78
# 67
# 72
# 75
# 89
# 73
# 85
# 96
# 76
# 77
# 92
# 70
# 85
# 73
# 71
# 84
# 78
# 59
# 79
# 76
# 68
# 80
# 92
# 80
# 82
# 82
# 89
# 82
# 92
# 92
# 75
# 75
# 89
# 84
# 80
# 94
# 85
# 68
# 61
# 86
# 79
# 78
# 85
# 75
# 64
# 86
# 69
# 92
# 69
# 76
# 81
# 60
# 80
# 70
# 75
# 70
# 71
# 76
# 85
# 81
# 72
# 94
# 76
# 67
# 68
# 80
# 76
# 76
# 75
# 91
# 70
# 77
# 67
# 76
# 74
# 73
# 83
# 81
# 74
# 71
# 90
# 74
# 66
# 90
# 75
# 80
# 84
# 90
# 86
# 77
# 91
# 75
# 78
# 81
# 74
# 85
# 81
# 95
# 79
# 80
# 71
# 85
# 69
# 97
# 76
# 80
# 78
# 75
# 83
# 67
# 70
# 73
# 78
# 65
# 81
# 78
# 77
# 72
# 67
# 83
# 85
# 85
# 75
# 70
# 80
# 73
# 69
# 85
# 78
# 87
# 71
# 81
# 77
# 74
# 85
# 93
# 72
# 89
# 82
# 68
# 87
# 67
# 80
# 67
# 73
# 75
# 80
# 83
# 80
# 64
# 81
# 62
# 71
# 97
# 80
# 75
# 80
# 79
# 72
# 65
# 70
# 73
# 77
# 86
# 78
# 85
# 75
# 75
# 77
# 79
# 70
# 70
# 77
# 70
# 70
# 83
# 76
# 90
# 74
# 88
# 68
# 77
# 72
# 67
# 84
# 82
# 66
# 75
# ...
