# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
FifaDB = pd.read_csv('NewFifa.csv')

# %%
from sklearn.model_selection import train_test_split
fifatrain, fifatest = train_test_split(FifaDB, test_size = 0.25)

# %%
FifaDB
# Out:
#                      Name  Overall  Potential      Value    Wage  \
# 0                L. Messi       94         94  110000000  565000
# 1       Cristiano Ronaldo       94         94   77000000  405000
# 2               Neymar Jr       92         93  118000000  290000
# 3            K. De Bruyne       91         92  102000000  355000
# 4               E. Hazard       91         91   93000000  340000
# ...                   ...      ...        ...        ...     ...
# 16117        J. Lundstram       47         65      60000    1000
# 16118  N. Christoffersson       47         63      60000    1000
# 16119           B. Worman       47         67      60000    1000
# 16120      D. Walker-Rice       47         66      60000    1000
# 16121           G. Nugent       46         66      60000    1000
#
#        Preferred Foot  Weak Foot  Skill Moves  Work Rate  Body Type  ...  \
# 0                   1        4.0          4.0          8          4  ...
# ...

# %%
list_lengths = np.array(FifaDB['Height'])
empty_list = []
for x in list_lengths:
    splitted_values = x.split("'")
    feet = (float(x[0])) + (float(x[2])/10)
    centimeters = feet * 30.48
    empty_list.append(round(centimeters))

print(empty_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9035a60beca0> in <module>()
#       2 empty_list = []
#       3 for x in list_lengths:
# ----> 4     splitted_values = x.split("'")
#       5     feet = (float(x[0])) + (float(x[2])/10)
#       6     centimeters = feet * 30.48
#
# AttributeError: 'numpy.int64' object has no attribute 'split'

# %%
list_wages = FifaDB['Wage']
wages = []
for i in list_wages:
    hoi = i.strip('K').strip('€')
    wage = int(hoi) * 1000
    wages.append(wage)
    
FifaDB['Wage'] = wages

# %%
list_values = FifaDB['Value']
values = []
for i in list_values[:10:]:
    if(i[-1]) == 'M':
        print(i.split('.').strip(''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-828ec526e3b8> in <module>()
#       3 for i in list_values[:10:]:
#       4     if(i[-1]) == 'M':
# ----> 5         print(i.split('.').strip(''))
#       6
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-b26d91648d88> in <module>()
# ----> 1 FifaDB()
#
# TypeError: 'DataFrame' object is not callable
