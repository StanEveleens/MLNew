# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
FifaDbfile = pd.read_csv('NewFifa.csv')

# %%
FifaDbfile
# Out:
#                      Name  Overall  Potential      Value    Wage  \
# 0                L. Messi       94         94  110000000  565000
# 1       Cristiano Ronaldo       94         94   77000000  405000
# 2               Neymar Jr       92         93  118000000  290000
# 3                  De Gea       91         93   72000000  260000
# 4            K. De Bruyne       91         92  102000000  355000
# ...                   ...      ...        ...        ...     ...
# 18142        J. Lundstram       47         65      60000    1000
# 18143  N. Christoffersson       47         63      60000    1000
# 18144           B. Worman       47         67      60000    1000
# 18145      D. Walker-Rice       47         66      60000    1000
# 18146           G. Nugent       46         66      60000    1000
#
#        Preferred Foot  Weak Foot  Skill Moves  Work Rate  Body Type  ...  \
# 0                   0        4.0          4.0          8          4  ...
# ...
